# %% [markdown]
# # E-Commerce Sales Intelligence
# ## Data Cleaning Notebook
# **Project:** E-Commerce Sales Intelligence: A Revenue Operations Case Study
# **Phase:** Phase 1 — Data Cleaning and Quality Assessment
# **Tool:** VS Code with Jupyter Extension
# **Dataset:** ecommerce_sales_raw.csv — 5,000 rows, 14 columns
#
# ---
#
# ### Purpose
# This notebook documents the full data cleaning process applied to the raw e-commerce sales dataset. Each step is tested here before the final version is transferred to `scripts/data_cleaning.py`.
#
# ---

# %% [markdown]
# ## Step 1 — Import Libraries
# Load the Python libraries needed for data cleaning and inspection.

# %%
# Import required libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ## Step 2 — Load the Dataset
# Load the raw CSV file into a pandas DataFrame for inspection.

# %%
# Load the raw dataset
# Code to be added during Phase 1

# %% [markdown]
# ## Step 3 — Initial Inspection
# Examine the structure, shape, column names, and data types.

# %%
# Initial inspection
# Code to be added during Phase 1

# %% [markdown]
# ## Step 4 — Check for Missing Values
# Identify any null or empty values across all columns.

# %%
# Missing value check
# Code to be added during Phase 1

# %% [markdown]
# ## Step 5 — Check for Duplicate Records
# Identify and handle any fully duplicated rows or duplicate Order IDs.

# %%
# Duplicate check
# Code to be added during Phase 1

# %% [markdown]
# ## Step 6 — Validate Data Types
# Confirm each column holds the correct data type and convert where necessary.

# %%
# Data type validation
# Code to be added during Phase 1

# %% [markdown]
# ## Step 7 — Validate the Sales Formula
# Confirm that Sales = Quantity x Unit Price x (1 - Discount / 100) for every row.

# %%
# Sales formula validation
# Code to be added during Phase 1

# %% [markdown]
# ## Step 8 — Identify and Document Outliers
# Use the IQR method to identify outliers in the Profit column and document findings.

# %%
# Outlier detection
# Code to be added during Phase 1

# %% [markdown]
# ## Step 9 — Export Cleaned Dataset
# Export the validated and cleaned dataset as a new CSV file.

# %%
# Export cleaned dataset
# Code to be added during Phase 1
